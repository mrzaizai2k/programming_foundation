# %% [markdown]
# # Introduction

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# ## System command

# %%
# !ls
# Out:
# sample_data

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# ## GPU

# %%
# !nvidia-smi
# Out:
# Wed Sep  3 11:56:54 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# ## Download datasets

# %%
#https://drive.google.com/file/d/1Do8SXKm4rmXW-phHlejV-udLfhSyYgKk/view?usp=sharing

# %%
# !gdown --id 1Do8SXKm4rmXW-phHlejV-udLfhSyYgKk
# Out:
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1Do8SXKm4rmXW-phHlejV-udLfhSyYgKk
# From (redirected): https://drive.google.com/uc?id=1Do8SXKm4rmXW-phHlejV-udLfhSyYgKk&confirm=t&uuid=c989e51a-3e0f-4662-a64c-d93ad9ef5bca
# To: /content/animals10small.zip
# 100% 46.3M/46.3M [00:01<00:00, 39.9MB/s]

# %%
# !ls
# Out:
# animals10small.zip  sample_data

# %%
# !unzip -q animals10small.zip

# %% [markdown]
# # Python

# %% [markdown]
# ## Function

# %%
def sum(a, c = 0):
  return a + c

sum(10)
# Out:
# 10

# %%
L = [10, 20]
sum(*L)
# Out:
# 30

# %%
V = {
    "a": 10,
    "c": 50
}
sum(**V)
# Out:
# 60

# %%
def foo(*L):
  return F.reduce(lambda a, b: a + b, L, 0)

foo(10, 20, 40)
# Out:
# 70

# %%
def goo(**D):
  print(type(D))

goo(a=10, b=20, c=30)
# Out:
# <class 'dict'>

# %%
goo
# Out:
# <function __main__.goo(**D)>

# %% [markdown]
# # New Section

# %% [markdown]
# ## Data types

# %%
L = [1, 2, 3]
T = (1, 2, 3)
S = {1, 2, 3}
D = {1: 2, 3: 4}

# %%
if 5 in L:
  print("5 is in L")
else:
  print("5 is not in L")
# Out:
# 5 is not in L

# %%
if 5 in S:
  print("5 is in S")
else:
  print("5 is not in S")
# Out:
# 5 is not in S

# %%
L1 = [1, "a", [1,3] ]
L1
# Out:
# [1, 'a', [1, 3]]

# %% [markdown]
# ### DICT
# key: value

# %%
name2idx = {
    "Cat": 0,
    "Dog": 1,
    "Chicken": 2,
    "Cow" : 3
}
name2idx
# Out:
# {'Cat': 0, 'Dog': 1, 'Chicken': 2, 'Cow': 3}

# %%
name2idx["Cat"]
# Out:
# 0

# %%
list(name2idx.keys())
# Out:
# ['Cat', 'Dog', 'Chicken', 'Cow']

# %%
list(name2idx.values())
# Out:
# [0, 1, 2, 3]

# %%
idx2name = dict(zip(name2idx.values(), name2idx.keys()))
idx2name
# Out:
# {0: 'Cat', 1: 'Dog', 2: 'Chicken', 3: 'Cow'}

# %%
name2idx.values()
# Out:
# dict_values([0, 1, 2, 3])

# %%
list(zip(name2idx.values(), name2idx.keys()))
# Out:
# [(0, 'Cat'), (1, 'Dog'), (2, 'Chicken'), (3, 'Cow')]

# %%
L1 = ['a', 'b', 'c']
L2 = [1, 2, 3, 4]
L3 = [10, 20, 30, 50, 80]
list(zip(L1, L2, L3))
# Out:
# [('a', 1, 10), ('b', 2, 20), ('c', 3, 30)]

# %%
L = list("ABCDEF")
L
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F']

# %% [markdown]
# ## Comprehension

# %%
L = list("ABCDEF")
L
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F']

# %%
for v in L:
  print(v)
# Out:
# A
# B
# C
# D
# E
# F

# %%
for idx, v in enumerate(L):
  print(idx, v)
# Out:
# 0 A
# 1 B
# 2 C
# 3 D
# 4 E
# 5 F

# %%
for idx in range(len(L)):
  print(idx, L[idx])
# Out:
# 0 A
# 1 B
# 2 C
# 3 D
# 4 E
# 5 F

# %%
Lin = list("ABCDEF")
Lout= []
for i in range(len(Lin)):
  Lout.append( "#" + Lin[i])

Lout
# Out:
# ['#A', '#B', '#C', '#D', '#E', '#F']

# %%
Lout2 = ["#" + v for v in Lin]
# Out:
# ['#A', '#B', '#C', '#D', '#E', '#F']

# %% [markdown]
# ### Demo

# %%
import os
import cv2
import matplotlib.pyplot as plt

path = "animals10small/data"
files = ["chicken/10.jpeg",
         "chicken/100.jpeg",
         "cat/1.jpeg",
         "cat/10.jpeg"]
fnames = [os.path.join(path, fn) for fn in files]
fnames
# Out:
# ['animals10small/data/chicken/10.jpeg',
#  'animals10small/data/chicken/100.jpeg',
#  'animals10small/data/cat/1.jpeg',
#  'animals10small/data/cat/10.jpeg']

# %%
images = [cv2.imread(fn, 0) for fn in fnames]
len(images)
# Out:
# 4

# %%
plt.figure()
plt.imshow(images[0], cmap="gray")
plt.axis("off")
plt.show()

# %%
rgb = [cv2.imread(fn, 1) for fn in fnames]
rgb = [cv2.cvtColor(img, cv2.COLOR_BGR2RGB) for img in rgb]

# %%
plt.figure()
plt.imshow(rgb[0])
plt.axis("off")
plt.show()

# %%
def show_image(image, title="An image"):
  plt.figure()
  if image.ndim == 2:
    plt.imshow(image, cmap="gray")
  elif image.ndim == 3:
    plt.imshow(image)
  else:
    raise Exception("Invalid image dimension")

  plt.axis("off")
  plt.title(title)
  plt.show()

# %%
show_image(rgb[0], "A Chicken")

# %%
import functools as F
L = [1, 2, 3, 5]


def ssum(a, b):
  print(a, ": ", b)
  return a + b
#F.reduce(lambda a, b: a + b, L, 0)
F.reduce(ssum, L, 0)
# Out:
# 0 :  1
# 1 :  2
# 3 :  3
# 6 :  5
# 11

# %%
F.reduce(lambda a, b: a * b, L, 1)
# Out:
# 30

# %%
S = 0
for v in L:
  S += v

S
# Out:
# 11

# %%
L = [1, 2, 4, 5, 7]

def process_per_item(x):
  return x % 2 == 0

#Lf = list(filter(lambda x: x % 2 == 0, L))
Lf = list(filter(process_per_item, L))
Lf
# Out:
# [2, 4]

# %%
L2 = map(lambda x: x ** 2, Lf)
list(L2)
# Out:
# [4, 16]

# %% [markdown]
# # EXamples

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# %%
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

trainset = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform)
testset = torchvision.datasets.MNIST(root='./data', train=False, download=True, transform=transform)

trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=False)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 18.4MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 505kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.61MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 4.47MB/s]

# %%
config = {
    "batch_size": 64,
    "num_workers": 2,
    "pin_memory": True
}

trainloader = torch.utils.data.DataLoader(trainset, shuffle=True, **config)
testloader = torch.utils.data.DataLoader(testset, shuffle=False, **config)

# %% [markdown]
# # Create file with Google colab

# %%
# %%writefile mylib.py
def print_info():
  print("This is a lib!")
# Out:
# Writing mylib.py

# %%
import os
if "./" not in os.sys.path:
  os.sys.path = ["./"] + os.sys.path

import mylib as lib
lib.print_info()
# Out:
# This is a lib!

# %%
from mylib import print_info
print_info()
# Out:
# This is a lib!
